# %%
# !python3 finetune.py --with_refine --datapath /home/nchris17/Documents/project_anynet/kitti2012/training/ \
    --pretrained /home/nchris17/Documents/project_anynet/checkpoints/checkpoint/sceneflow/sceneflow.tar --datatype '2012'\
--split_file /home/nchris17/Documents/project_anynet/checkpoints/checkpoint/kitti2012_ck/split.txt \
# Out:
# [2023-04-17 20:21:39 KITTIloader2012.py:34] INFO     ['000004_10.png', '000005_10.png', '000006_10.png', '000009_10.png', '000020_10.png', '000021_10.png', '000029_10.png', '000035_10.png', '000040_10.png', '000055_10.png', '000056_10.png', '000058_10.png', '000062_10.png', '000063_10.png', '000066_10.png', '000071_10.png', '000072_10.png', '000075_10.png', '000076_10.png', '000083_10.png', '000084_10.png', '000086_10.png', '000089_10.png', '000099_10.png', '000104_10.png', '000111_10.png', '000119_10.png', '000127_10.png', '000128_10.png', '000131_10.png', '000158_10.png', '000164_10.png', '000172_10.png', '000191_10.png']
# [2023-04-17 20:21:39 finetune.py:92] INFO     datapath: /home/nchris17/Documents/project_anynet/kitti2012/training/
# [2023-04-17 20:21:39 finetune.py:92] INFO     datatype: 2012
# [2023-04-17 20:21:39 finetune.py:92] INFO     epochs: 300
# [2023-04-17 20:21:39 finetune.py:92] INFO     evaluate: False
# ...

# %%
# %cd AnyNet2/AnyNet/
# Out:
# [Errno 2] No such file or directory: 'AnyNet2/AnyNet/'
# /home/nchris17/Documents/project_anynet/AnyNet2/AnyNet

# %%
# !python3 submission.py --with_refine --maxdisp 192 --datapath /home/nchris17/Documents/project_anynet/kitti2012/testing/ \
--datatype 2012 \
--loadmodel /home/nchris17/Documents/project_anynet/AnyNet2/AnyNet/results/finetune_anynet/checkpoint.tar\
--output_dir /home/nchris17/Documents/project_anynet/results/
# Out:
# Number of model parameters: 36140
# time = 0.03:   3%|▊                             | 5/195 [00:01<00:28,  6.58it/s]/home/nchris17/Documents/project_anynet/AnyNet2/AnyNet/submission.py:119: RuntimeWarning: invalid value encountered in log10
#   img_log_scale = np.log10(img)
# time = 0.03: 100%|████████████████████████████| 195/195 [00:17<00:00, 11.09it/s]

# %%
cd ../../
# Out:
# /home/nchris17/Documents/project_anynet
